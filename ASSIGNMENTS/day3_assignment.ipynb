# %%
Firstname = ("Rijan")
Lastname = ("Rana")
Address = ("imadple,Ratamakai")
Course = ("data science")
Contact = ("978490248")
Gender = ("   Male   ")
City =("Kathmandu")
Country =( "Nepal")
Dream_job = ("Data Scientist")
Fev_food =("momo")

# %% [markdown]
# # ASSIGNMENT ONE (1)
#
# Question is avilable in day_3 last slide

# %%
#Applying the different methods

print(Firstname.lower()) # lower()
# Out:
# rijan

# %%
print(Lastname.upper()) # upper()
# Out:
# RANA

# %%
print(Address.capitalize()) # capitalize (): capitalize the first letter only
# Out:
# Imadple,ratamakai

# %%
print (Course.title()) # title(): capitalize the first letter of every word
# Out:
# Data Science

# %%
print(Gender.strip()) #strip(): remove white space from both ends
# Out:
# Male

# %%
print(Country.replace('Nepal','UK')) #replace is use to replace the before data by new data
# Out:
# UK

# %%
print(City.split('a'))  #split is use to split he certain thing passed as an argument
# Out:
# ['K', 'thm', 'ndu']

# %%
print(Gender.lstrip()) #lstrip is used to remove the whitespace (spaces, tabs, newlines)
                       #or specified characters from the beginning (left side) of a string.
# Out:
# Male

# %%
print(Firstname.isupper()) # its check if the value is in upper case or not and return the boolen value
# Out:
# False

# %%
print(Dream_job.isspace()) # its returns true if all character are whitespace
# Out:
# False

# %%
print(Contact.isdigit()) # it return true if the given value is digit otherwise false
# Out:
# True
