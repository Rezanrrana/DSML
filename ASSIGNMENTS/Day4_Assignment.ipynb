# %% [markdown]
# # ASSIGNMENT TWO (2)

# %% [markdown]
# Q1) CREAT A LIST OF 5 FAVOURATE FRUITS. ADD ONE    MORE FRUIT USING APPEND() AND PRINT UPDATED FILE.

# %%
Fav_fruits = ["Mango","Banana","Apple","Grapes","Orange"]
Fav_fruits.append("Kiwi")
print(Fav_fruits)
# Out:
# ['Mango', 'Banana', 'Apple', 'Grapes', 'Orange', 'Kiwi']

# %% [markdown]
# Q2)  CREAT A LIST OF NUMBERS FROM 1 TO 5. REMOVE THE LAST ITEM USING POP() AND PRINT THE FINAL

# %%
List = [1,2,3,4,5]

# %%
List.pop(4)
# Out:
# 5

# %%
print(List)
# Out:
# [1, 2, 3, 4]
