# %%
# in python function is creat using def key word
# def <function name>: sum(a,b) = parameter, sum(4,5)= arguments
 # code block
 # return

# %% [markdown]
# ![Screenshot 2026-07-16 180206.png](data:image/png;base64,...)

# %% [markdown]
# **USER DEFINE FUNCTION**
#
# ![Screenshot 2026-07-16 180227.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-07-16 180243.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-07-16 180316.png](data:image/png;base64,...)

# %%
def sum (a,b):
  return a+b

# %%
sum(5,4)
# Out:
# 9

# %% [markdown]
# **Function types**
#
#
# 1.   No parameter, no return type
# 3.   Has parameter, no return type
# 2.   No parameter, no return type
# 4.   Has parameter, has return type

# %% [markdown]
# ![Screenshot 2026-07-16 180908.png](data:image/png;base64,...)

# %%
# 1. No parameter, No return type

def greet ():
  print("Hello! Welcome to skillshikshya")

# %%
# function call

greet()
# Out:
# Hello! Welcome to skillshikshya

# %% [markdown]
# ![Screenshot 2026-07-16 181024.png](data:image/png;base64,...)

# %%
# 2. No parameter, has return type

def get_pi():
  pi = 3.4
  return pi

# %%
value = get_pi()
print("Value of pi:", value)
# Out:
# Value of pi: 3.4

# %%
# or
get_pi()
# Out:
# 3.4

# %% [markdown]
# ![Screenshot 2026-07-16 181040.png](data:image/png;base64,...)

# %%
# 3. Has parameter, no return type

def greet(name):
 print(f"Hello, {name} !")

# %%
greet("Rezan")
# Out:
# Hello, Rezan !

# %% [markdown]
# ![Screenshot 2026-07-16 181052.png](data:image/png;base64,...)

# %%
# 4. Has parameter, has return type

def add(a,b):
  sum = a+b
  return sum

# %%
   # function call

  result = add (10,30)
  print("sum is: ", result)
# Out:
# sum is:  40

# %% [markdown]
# ![Screenshot 2026-07-16 181240.png](data:image/png;base64,...)

# %%
# class task

# one
def area(length,breadth):
 return("The area of the rectangle is :", length*breadth)

# %%
 area(10,20)
# Out:
# ('The area of the rectangle is :', 200)

# %%
# 2

def calculator(num1, num2, operator):

    if operator == '+':
        return num1 + num2
    elif operator == '-':
        return num1 - num2
    elif operator == '*':
        return num1 * num2
    elif operator == '/':
        return num1 / num2
    else:
        return "Invalid operator"

# Take input from the user

first = float(input("Enter the first number: "))
second = float(input("Enter the second number: "))
ope = input("Enter the operator (+, -, *, /): ")

result = calculator(first,second, ope)
print("Reault:", result)
# Out:
# Enter the first number: 30
# Enter the second number: 40
# Enter the operator (+, -, *, /): /
# Reault: 0.75

# %% [markdown]
# ![Screenshot 2026-07-16 181254.png](data:image/png;base64,...)

# %%
# 3

def lst_operation():
 number = []
 for i in range(5):
  value = input(f"Enter number {i+1}: ")
  if "." in value:
    if len(number) > 0:
      removed = number.pop()
      print(f" Float detected. removed:{removed}")
    else:
      print("float detected, but the list is empty")
 else:
    number.append(int(value))
    print(f"Integer {value} added to the list ")
 print("Upadated list:", number)

# %%
lst_operation()
