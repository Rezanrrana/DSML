# %% [markdown]
# **CONDITION AND BRANCHING**
#
# At first what is cinditions
#
# ![Screenshot 2026-07-14 144505.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-07-14 144625.png](data:image/png;base64,...)

# %%
# Conditions
# 1. If
# 2. elif
# 3. else

# %% [markdown]
# ![Screenshot 2026-07-14 144835.png](data:image/png;base64,...)

# %%
number = 9
if(number > 20):
  print("here")

# %% [markdown]
# ![Screenshot 2026-07-14 144855.png](data:image/png;base64,...)

# %%
age = 10
if age <=12:
  print("Travel for free")
else:
  print("pay for ticket")
# Out:
# Travel for free

# %% [markdown]
# ![Screenshot 2026-07-14 145126.png](data:image/png;base64,...)

# %%
age = 25
if age <= 12:
  print("child")
elif age <=19:
  print("Teeneger")
elif age <= 35:
  print(" Young adult")
else:
  print ("Adult")
# Out:
#  Young adult

# %%
# Voating Machine class task

User bata input age lini

# vote halna paucha ke paudaina
#condition, age 18+ citizenship

# %% [markdown]
# ![Screenshot 2026-07-14 145213.png](data:image/png;base64,...)

# %%
age = int(input(" Enter your age"))

if age >= 18:
 citizenship = input(" Do you have a citizenship? (yes/no)")
 if citizenship.lower() == "Yes":
   print("You are eligiable to vote")
 else:
  print("You are not eligiable to vote")
else:
   print ("your are under 18")
# Out:
#  Enter your age20
#  Do you have a citizenship? (yes/no)yes
# You are not eligiable to vote

# %%
# TASK 2
# age 60 bhanda mathi cha and membership cha bhani 30 % discount
# age 60 bhanda mathi xa but membership chainw bhani 20 % discount
# " not eligible for a senior discount"

# %%
age = 70

is_member =True  # to set a boolen value, easy to check the contition
                # only for boolen ( is_..... )
if age >= 60:
  if is_member:
    print("30% discount")
  else:
   print("20 discount")
else:
  print("not eligible for a seniot discount")
# Out:
# 30% discount

# %% [markdown]
# **TERNERY OPERATOR**

# %%
# value_if_true if condition else value_if_false

n =int(input("Enter a number"))
print("Even" if (n % 2 == 0) else "Odd")
# Out:
# Enter a number19
# Odd

# %% [markdown]
# ![Screenshot 2026-07-14 145315.png](data:image/png;base64,...)

# %%
# CLASS TASK

marks = int(input(" Enter your marks"))

if marks >=90:
 print (" You have recived gread A+: outstanding")
elif marks >=80:
 print(" You have received gread A:Excellent ")
elif marks >= 70:
  print("  You have received gread B+: Very Good")
elif marks >= 60:
  print("  You have received gread B: Good")
elif marks >= 50:
  print("  You have received gread C: Average")
elif marks >= 40:
  print("  You have received gread D: Poor")
else:
  print("You have failed")
# Out:
#  Enter your marks44
#   You have received gread D: Poor

# %% [markdown]
# **OPERATORS**
#
# Operators are used to chek boolen value either true or false
#
# ![Screenshot 2026-07-14 145427.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-07-14 145537.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-07-14 145552.png](data:image/png;base64,...)

# %%
2 == 2
# Out:
# True

# %%
2 != 1
# Out:
# True

# %%
2 > 3
# Out:
# False

# %%
# AND OPERATORE


age = 20
Citizenship = True

if age >= 18 and citizenship: # AND operator is used
  print("Eligible to vot")
else:
  print(
      "not eligible"
  )
# Out:
# Eligible to vot

# %%
# OR operatore

username = "admin"
password = "1234"

if username == "admin" or password == "admin1234":
  print ("Acess granted")
else:
  print("not granted")
# Out:
# Acess granted

# %%
# NOR operatore

is_logged_in = False
if not is_logged_in:
  print("please login first")
# Out:
# please login first

# %%
# by using and operator

age = int (input(" Enter your age:"))
citizenship = input("Do you have a citizenship? (yes/no)")

if age >= 18 and citizenship.lower() == "yes":
  print("Eligible")
else:
  print("Not eligible")
# Out:
#  Enter your age:20
# Do you have a citizenship? (yes/no)no
# Not eligible

# %% [markdown]
# **CLASS TASK**
#
# 1. Check if a number is +ve and even
# 2. Checi if a user logged in
# 3. Check if a age between 18 and 60 using AND
# 4. Check if a day ia Satarday or Sunday using OR

# %%
# question number one
number = int(input(" Enter the number "))

if number >0 and number % 2 == 0:
  print("Number is +ve and even")
else:
  print(
      "invvvvvvvalid"
  )
# Out:
#  Enter the number 20
# Number is +ve and even

# %%
#   question number 2

is_logged_in = False
if not is_logged_in:
  print("please login first")
# Out:
# please login first

# %%
# Question number 3

age = int(input("enter the age"))

if age >18 and age <60:
  print("age is between 18 and 60")
else:
  print("age is not between 18 and 6o")
# Out:
# enter the age40
# age is between 18 and 60

# %%
# Question number 4

day = str(input("Enter the day: "))

if day == "Saturday" or day == "Sunday":
  print("It is a weekend")
else:
  print("It is working day")
# Out:
# Enter the day: Saturday
# It is a weekend

# %% [markdown]
# OPERATORS AND SIGNE
#
# && AND
#
# || OR

# %%
# any() with if condition

is_admin = False
is_teacher = False

if any([is_admin, is_teacher]):
    print("Access granted")
